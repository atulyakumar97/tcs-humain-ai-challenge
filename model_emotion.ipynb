# %% [markdown]
# ### Importing Libraries

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import InputLayer
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

#TL pecific modules
#from keras.applications.resnet50 import ResNet50
#from keras.applications.vgg16 import VGG16
# !pip install keras_vggface
from keras_vggface.vggface import VGGFace
# Out:
# Using TensorFlow backend.
# Collecting keras_vggface
#   Downloading https://files.pythonhosted.org/packages/2f/7d/5f0319ebdc09ac1a2272364fa9583f5067b6f8aff93fbbf8835d81cbaad7/keras_vggface-0.6-py3-none-any.whl
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (5.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.17.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (5.4.1)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.2.1)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (2.9.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.12.0)
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (2.2.4)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras_vggface) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras_vggface) (1.1.0)
# Installing collected packages: keras-vggface
# Successfully installed keras-vggface-0.6

# %%
os.listdir('../input/humain/dataset')
# Out:
# ['ethnicity', 'gender', 'vgg_face_weights.h5', 'emotion', 'age']

# %%
def assign_label(img,label):
    return label

# %%
def make_train_data(label,DIR):
    for img in tqdm(os.listdir(DIR)):
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %% [markdown]
# ### **Importing Pre-trained Model VGG Face for Transfer Learning**

# %%
base_model=VGGFace(include_top=False, weights=None,input_shape=(150,150,3), pooling='avg')

weights_path='../input/humain/dataset/vgg_face_weights.h5' # 16 to 13 layers
base_model.load_weights(weights_path,by_name='True')

# %% [markdown]
# ## Emotion Model
#
# There will be 4 seperate models trained to predict age, gender, ethnicity and emotion.
#
# Training Approach : Transfer learning on a pre-trained vggface convolutional neural network.

# %%
X=[]
Z=[]
IMG_SIZE=150
EMOTION_ANGRY_DIR='../input/humain/dataset/emotion/Emotion_Angry'
EMOTION_HAPPY_DIR='../input/humain/dataset/emotion/Emotion_Happy'
EMOTION_NEUTRAL_DIR='../input/humain/dataset/emotion/Emotion_Neutral'
EMOTION_SAD_DIR='../input/humain/dataset/emotion/Emotion_Sad'

make_train_data('Angry',EMOTION_ANGRY_DIR)
make_train_data('Happy',EMOTION_HAPPY_DIR)
make_train_data('Neutral',EMOTION_NEUTRAL_DIR)
make_train_data('Sad',EMOTION_SAD_DIR)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 130.97it/s]
# 100%|██████████| 68/68 [00:00<00:00, 365.12it/s]
# 100%|██████████| 126/126 [00:00<00:00, 358.94it/s]
# 100%|██████████| 10/10 [00:00<00:00, 361.44it/s]

# %%
fig,ax=plt.subplots(2,5)
plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
fig.set_size_inches(10,10)

for i in range(2):
    for j in range (5):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l][:,:,::-1])
        ax[i,j].set_title('Emotion: '+Z[l])
        ax[i,j].set_aspect('equal')

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,4)
X=np.array(X)
X=X/255

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=1337)

np.random.seed(42)
rn.seed(42)
tf.set_random_seed(42)

# %%
emotionmodel=Sequential()
emotionmodel.add(base_model)
emotionmodel.add(Dropout(0.3))
emotionmodel.add(Dense(256,activation='relu'))
emotionmodel.add(Dropout(0.25))
emotionmodel.add(Dense(128,activation='relu'))
emotionmodel.add(Dropout(0.20))
emotionmodel.add(Dense(64,activation='relu', kernel_regularizer=regularizers.l2(0.001), activity_regularizer=regularizers.l1(0.001)))
emotionmodel.add(Dropout(0.15))
emotionmodel.add(Dense(4,activation='softmax'))

# %% [markdown]
# ### **Data Augmentation **

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ### Model Architechture

# %%
epochs=200
batch_size=32
red_lr=ReduceLROnPlateau(monitor='val_acc', factor=0.1, min_delta=0.00001, patience=2, verbose=1)

base_model.trainable=True # setting the VGG model to be trainable.
emotionmodel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vggface_vgg16 (Model)        (None, 512)               14714688
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 14,887,428
# Trainable params: 14,887,428
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training Model

# %%
emotionmodel.compile(optimizer=Adam(lr=1e-5),loss='categorical_crossentropy',metrics=['accuracy'])

History = emotionmodel.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)

emotionmodel.save('../working/emotionmodel.h5')
# Out:
# Epoch 1/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.5091 - acc: 0.1641 - val_loss: 1.4845 - val_acc: 0.2264
# Epoch 2/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4917 - acc: 0.1106 - val_loss: 1.4786 - val_acc: 0.2453
# Epoch 3/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4849 - acc: 0.1423 - val_loss: 1.4756 - val_acc: 0.2642
# Epoch 4/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4792 - acc: 0.1993 - val_loss: 1.4738 - val_acc: 0.2830
# Epoch 5/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4776 - acc: 0.2389 - val_loss: 1.4722 - val_acc: 0.4340
# Epoch 6/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4762 - acc: 0.2422 - val_loss: 1.4714 - val_acc: 0.4151
# Epoch 7/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4745 - acc: 0.2999 - val_loss: 1.4707 - val_acc: 0.4717
# Epoch 8/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4732 - acc: 0.2224 - val_loss: 1.4702 - val_acc: 0.4528
# Epoch 9/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4727 - acc: 0.3242 - val_loss: 1.4697 - val_acc: 0.4717
# Epoch 10/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4718 - acc: 0.3568 - val_loss: 1.4693 - val_acc: 0.4717
# Epoch 11/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4711 - acc: 0.4062 - val_loss: 1.4690 - val_acc: 0.4717
# Epoch 12/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4705 - acc: 0.4517 - val_loss: 1.4687 - val_acc: 0.4528
# Epoch 13/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4701 - acc: 0.5078 - val_loss: 1.4684 - val_acc: 0.5283
# Epoch 14/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4696 - acc: 0.4917 - val_loss: 1.4681 - val_acc: 0.5849
# Epoch 15/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4692 - acc: 0.5252 - val_loss: 1.4676 - val_acc: 0.6226
# Epoch 16/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4689 - acc: 0.6250 - val_loss: 1.4674 - val_acc: 0.6415
# Epoch 17/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4687 - acc: 0.6048 - val_loss: 1.4670 - val_acc: 0.6226
# Epoch 18/200
# 4/4 [==============================] - 59s 15s/step - loss: 1.4684 - acc: 0.6027 - val_loss: 1.4666 - val_acc: 0.6226
# Epoch 19/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.4675 - acc: 0.6353 - val_loss: 1.4662 - val_acc: 0.6226
# Epoch 20/200
# 4/4 [==============================] - 58s 15s/step - loss: 1.
200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7628 - acc: 0.9125 - val_loss: 1.1819 - val_acc: 0.7170
# Epoch 174/200
# 4/4 [==============================] - 58s 15s/step - loss: 0.8131 - acc: 0.9121 - val_loss: 1.1276 - val_acc: 0.7547
# Epoch 175/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.8120 - acc: 0.8973 - val_loss: 1.0902 - val_acc: 0.7925
# Epoch 176/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7980 - acc: 0.8828 - val_loss: 1.1629 - val_acc: 0.7736
# Epoch 177/200
# 4/4 [==============================] - 58s 15s/step - loss: 0.7545 - acc: 0.9286 - val_loss: 1.1335 - val_acc: 0.7547
# Epoch 178/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7865 - acc: 0.8890 - val_loss: 1.1182 - val_acc: 0.7925
# Epoch 179/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7945 - acc: 0.8890 - val_loss: 1.0940 - val_acc: 0.7925
# Epoch 180/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7840 - acc: 0.9204 - val_loss: 1.1372 - val_acc: 0.7358
# Epoch 181/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.8054 - acc: 0.8906 - val_loss: 1.1192 - val_acc: 0.7736
# Epoch 182/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7473 - acc: 0.9290 - val_loss: 1.0948 - val_acc: 0.7925
# Epoch 183/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.8064 - acc: 0.8886 - val_loss: 1.1276 - val_acc: 0.7736
# Epoch 184/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7943 - acc: 0.9047 - val_loss: 1.1364 - val_acc: 0.7358
# Epoch 185/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7716 - acc: 0.9130 - val_loss: 1.1350 - val_acc: 0.7736
# Epoch 186/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7914 - acc: 0.8984 - val_loss: 1.1004 - val_acc: 0.7736
# Epoch 187/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7547 - acc: 0.9286 - val_loss: 1.1227 - val_acc: 0.7358
# Epoch 188/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7409 - acc: 0.9282 - val_loss: 1.1232 - val_acc: 0.7358
# Epoch 189/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7888 - acc: 0.8820 - val_loss: 1.1023 - val_acc: 0.7925
# Epoch 190/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7694 - acc: 0.9286 - val_loss: 1.1111 - val_acc: 0.8113
# Epoch 191/200
# 4/4 [==============================] - 60s 15s/step - loss: 0.7674 - acc: 0.9141 - val_loss: 1.0835 - val_acc: 0.7925
# Epoch 192/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7931 - acc: 0.8738 - val_loss: 1.1005 - val_acc: 0.7925
# Epoch 193/200
# 4/4 [==============================] - 60s 15s/step - loss: 0.7240 - acc: 0.9447 - val_loss: 1.1399 - val_acc: 0.7358
# Epoch 194/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7636 - acc: 0.8973 - val_loss: 1.0825 - val_acc: 0.7925
# Epoch 195/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7943 - acc: 0.8729 - val_loss: 1.0588 - val_acc: 0.7925
# Epoch 196/200
# 4/4 [==============================] - 60s 15s/step - loss: 0.7591 - acc: 0.9219 - val_loss: 1.1202 - val_acc: 0.7547
# Epoch 197/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7734 - acc: 0.8886 - val_loss: 1.0818 - val_acc: 0.7925
# Epoch 198/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7675 - acc: 0.8973 - val_loss: 1.0850 - val_acc: 0.7925
# Epoch 199/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7623 - acc: 0.9055 - val_loss: 1.1560 - val_acc: 0.7358
# Epoch 200/200
# 4/4 [==============================] - 59s 15s/step - loss: 0.7611 - acc: 0.9138 - val_loss: 1.0828 - val_acc: 0.7925

# %%
plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %% [markdown]
# ### Importing Libraries

# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras import regularizers
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import InputLayer
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

#TL pecific modules
#from keras.applications.resnet50 import ResNet50
#from keras.applications.vgg16 import VGG16
# !pip install keras_vggface
from keras_vggface.vggface import VGGFace
# Out:
# Using TensorFlow backend.
# Collecting keras_vggface
#   Downloading https://files.pythonhosted.org/packages/2f/7d/5f0319ebdc09ac1a2272364fa9583f5067b6f8aff93fbbf8835d81cbaad7/keras_vggface-0.6-py3-none-any.whl
# Requirement already satisfied: keras in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (2.2.4)
# Requirement already satisfied: scipy>=0.14 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.2.1)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.17.0)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (2.9.0)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (1.12.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (5.4.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.6/site-packages (from keras_vggface) (5.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.6/site-packages (from keras->keras_vggface) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.6/site-packages (from keras->keras_vggface) (1.1.0)
# Installing collected packages: keras-vggface
# Successfully installed keras-vggface-0.6

# %%
os.listdir('../input/humain/dataset')
# Out:
# ['age', 'gender', 'emotion', 'vgg_face_weights.h5', 'ethnicity']

# %%
def assign_label(img,label):
    return label

# %%
def make_train_data(label,DIR):
    for img in tqdm(os.listdir(DIR)):
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
        
        X.append(np.array(img))
        Z.append(str(label))

# %% [markdown]
# ### **Importing Pre-trained Model VGG Face for Transfer Learning**

# %%
base_model=VGGFace(include_top=False, weights=None,input_shape=(150,150,3), pooling='avg')

weights_path='../input/humain/dataset/vgg_face_weights.h5' # 16 to 13 layers
base_model.load_weights(weights_path,by_name='True')

# %% [markdown]
# ## Age Model
#
# There will be 4 seperate models trained to predict age, gender, ethnicity and emotion.
#
# Training Approach : Transfer learning on a pre-trained vggface convolutional neural network.

# %%
X=[]
Z=[]
IMG_SIZE=150
AGE_20_30_DIR='../input/humain/dataset/age/Age_20_30'
AGE_30_40_DIR='../input/humain/dataset/age/Age_30_40'
AGE_40_50_DIR='../input/humain/dataset/age/Age_40_50'
AGE_ABOVE_50_DIR='../input/humain/dataset/age/Age_above_50'
AGE_BELOW_20_DIR='../input/humain/dataset/age/Age_below20'


make_train_data('AGE_20_30',AGE_20_30_DIR)
make_train_data('AGE_30_40',AGE_30_40_DIR)
make_train_data('AGE_40_50',AGE_40_50_DIR)
make_train_data('AGE_ABOVE_50',AGE_ABOVE_50_DIR)
make_train_data('AGE_BELOW_20',AGE_BELOW_20_DIR)
# Out:
# 100%|██████████| 93/93 [00:00<00:00, 356.50it/s]
# 100%|██████████| 65/65 [00:00<00:00, 456.39it/s]
# 100%|██████████| 18/18 [00:00<00:00, 371.99it/s]
# 100%|██████████| 16/16 [00:00<00:00, 410.53it/s]
# 100%|██████████| 19/19 [00:00<00:00, 225.90it/s]

# %%
fig,ax=plt.subplots(2,5)
plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
fig.set_size_inches(10,10)

for i in range(2):
    for j in range (5):
        l=rn.randint(0,len(Z))
        ax[i,j].imshow(X[l][:,:,::-1])
        ax[i,j].set_title(Z[l])
        ax[i,j].set_aspect('equal')

# %%
le=LabelEncoder()
Y=le.fit_transform(Z)
Y=to_categorical(Y,5)
X=np.array(X)
X=X/255

x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=1337)

np.random.seed(42)
rn.seed(42)
tf.set_random_seed(42)

# %%
agemodel=Sequential()
agemodel.add(base_model)
agemodel.add(Dropout(0.3))
agemodel.add(Dense(256,activation='relu'))
agemodel.add(Dropout(0.25))
agemodel.add(Dense(128,activation='relu'))
agemodel.add(Dropout(0.20))
agemodel.add(Dense(64,activation='relu', kernel_regularizer=regularizers.l2(0.001), activity_regularizer=regularizers.l1(0.001)))
agemodel.add(Dropout(0.15))
agemodel.add(Dense(5,activation='softmax'))

# %% [markdown]
# ### **Data Augmentation **

# %%
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %% [markdown]
# ### Model Architechture

# %%
epochs=200
batch_size=32
red_lr=ReduceLROnPlateau(monitor='val_acc', factor=0.1, min_delta=0.00001, patience=2, verbose=1)

base_model.trainable=True # setting the VGG model to be trainable.
agemodel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vggface_vgg16 (Model)        (None, 512)               14714688
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 14,887,493
# Trainable params: 14,887,493
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training Model

# %%
agemodel.compile(optimizer=Adam(lr=1e-5),loss='categorical_crossentropy',metrics=['accuracy'])

History = agemodel.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_test,y_test),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size)

agemodel.save('../working/agemodel.h5')
# Out:
# Epoch 1/200
# 4/4 [==============================] - 65s 16s/step - loss: 1.7079 - acc: 0.4297 - val_loss: 1.6946 - val_acc: 0.4717
# Epoch 2/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6992 - acc: 0.4270 - val_loss: 1.6930 - val_acc: 0.4717
# Epoch 3/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.7045 - acc: 0.3643 - val_loss: 1.6919 - val_acc: 0.4717
# Epoch 4/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6927 - acc: 0.4777 - val_loss: 1.6911 - val_acc: 0.4717
# Epoch 5/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6975 - acc: 0.4039 - val_loss: 1.6897 - val_acc: 0.4717
# Epoch 6/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6942 - acc: 0.4688 - val_loss: 1.6887 - val_acc: 0.4717
# Epoch 7/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6910 - acc: 0.4187 - val_loss: 1.6873 - val_acc: 0.4717
# Epoch 8/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6949 - acc: 0.4051 - val_loss: 1.6857 - val_acc: 0.4717
# Epoch 9/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6925 - acc: 0.4439 - val_loss: 1.6841 - val_acc: 0.4717
# Epoch 10/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6939 - acc: 0.4039 - val_loss: 1.6821 - val_acc: 0.4717
# Epoch 11/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6843 - acc: 0.4375 - val_loss: 1.6801 - val_acc: 0.4717
# Epoch 12/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6899 - acc: 0.4282 - val_loss: 1.6772 - val_acc: 0.4717
# Epoch 13/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6777 - acc: 0.4835 - val_loss: 1.6729 - val_acc: 0.4717
# Epoch 14/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6870 - acc: 0.3973 - val_loss: 1.6686 - val_acc: 0.4717
# Epoch 15/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6824 - acc: 0.4055 - val_loss: 1.6622 - val_acc: 0.4717
# Epoch 16/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.6714 - acc: 0.4453 - val_loss: 1.6542 - val_acc: 0.4717
# Epoch 17/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6721 - acc: 0.4200 - val_loss: 1.6438 - val_acc: 0.4717
# Epoch 18/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6578 - acc: 0.4216 - val_loss: 1.6310 - val_acc: 0.4717
# Epoch 19/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6622 - acc: 0.4130 - val_loss: 1.6199 - val_acc: 0.4717
# Epoch 20/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6361 - acc: 0.4517 - val_loss: 1.6097 - val_acc: 0.4717
# Epoch 21/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6413 - acc: 0.4297 - val_loss: 1.6091 - val_acc: 0.4717
# Epoch 22/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6608 - acc: 0.4208 - val_loss: 1.6164 - val_acc: 0.4717
# Epoch 23/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6088 - acc: 0.4526 - val_loss: 1.6015 - val_acc: 0.4717
# Epoch 24/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6197 - acc: 0.4195 - val_loss: 1.5843 - val_acc: 0.4717
# Epoch 25/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6135 - acc: 0.4282 - val_loss: 1.5789 - val_acc: 0.4717
# Epoch 26/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6253 - acc: 0.4453 - val_loss: 1.5718 - val_acc: 0.4717
# Epoch 27/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.6260 - acc: 0.4278 - val_loss: 1.5872 - val_acc: 0.4717
# Epoch 28/200
# 4/4 [==============================] - 60s 15s/step - loss: 1.6233 - acc: 0.3969 - val_loss: 1.5884 - val_acc: 0.4717
# Epoch 29/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.
200
# 4/4 [==============================] - 61s 15s/step - loss: 1.2372 - acc: 0.6976 - val_loss: 1.5093 - val_acc: 0.5472
# Epoch 168/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1336 - acc: 0.7772 - val_loss: 1.5147 - val_acc: 0.5472
# Epoch 169/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.2305 - acc: 0.6733 - val_loss: 1.5169 - val_acc: 0.5849
# Epoch 170/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.1545 - acc: 0.7541 - val_loss: 1.5139 - val_acc: 0.5283
# Epoch 171/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1549 - acc: 0.7344 - val_loss: 1.5657 - val_acc: 0.5472
# Epoch 172/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1546 - acc: 0.7302 - val_loss: 1.5510 - val_acc: 0.4717
# Epoch 173/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.1420 - acc: 0.7698 - val_loss: 1.5529 - val_acc: 0.5849
# Epoch 174/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1941 - acc: 0.7380 - val_loss: 1.5461 - val_acc: 0.5472
# Epoch 175/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.1265 - acc: 0.7776 - val_loss: 1.5677 - val_acc: 0.4717
# Epoch 176/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1141 - acc: 0.7734 - val_loss: 1.5878 - val_acc: 0.5283
# Epoch 177/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1454 - acc: 0.7438 - val_loss: 1.5315 - val_acc: 0.5283
# Epoch 178/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.1951 - acc: 0.7050 - val_loss: 1.5567 - val_acc: 0.5660
# Epoch 179/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1491 - acc: 0.7533 - val_loss: 1.5438 - val_acc: 0.5283
# Epoch 180/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1421 - acc: 0.7467 - val_loss: 1.5123 - val_acc: 0.5283
# Epoch 181/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1326 - acc: 0.7812 - val_loss: 1.5246 - val_acc: 0.5283
# Epoch 182/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.0666 - acc: 0.8333 - val_loss: 1.5825 - val_acc: 0.5283
# Epoch 183/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1628 - acc: 0.6811 - val_loss: 1.5622 - val_acc: 0.5283
# Epoch 184/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1572 - acc: 0.7706 - val_loss: 1.5614 - val_acc: 0.5660
# Epoch 185/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1208 - acc: 0.7533 - val_loss: 1.5886 - val_acc: 0.5094
# Epoch 186/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1052 - acc: 0.7656 - val_loss: 1.5924 - val_acc: 0.5283
# Epoch 187/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.0873 - acc: 0.7376 - val_loss: 1.5806 - val_acc: 0.5283
# Epoch 188/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1219 - acc: 0.7698 - val_loss: 1.5733 - val_acc: 0.5472
# Epoch 189/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.0610 - acc: 0.7842 - val_loss: 1.5786 - val_acc: 0.5472
# Epoch 190/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1025 - acc: 0.7306 - val_loss: 1.5754 - val_acc: 0.5472
# Epoch 191/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1055 - acc: 0.7422 - val_loss: 1.5639 - val_acc: 0.5283
# Epoch 192/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.0895 - acc: 0.7385 - val_loss: 1.5625 - val_acc: 0.5472
# Epoch 193/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.0909 - acc: 0.7776 - val_loss: 1.5808 - val_acc: 0.5283
# Epoch 194/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.0450 - acc: 0.8086 - val_loss: 1.5670 - val_acc: 0.5283
# Epoch 195/200
# 4/4 [==============================] - 62s 15s/step - loss: 1.1051 - acc: 0.7368 - val_loss: 1.5729 - val_acc: 0.5283
# Epoch 196/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.1010 - acc: 0.7500 - val_loss: 1.5655 - val_acc: 0.5283
# Epoch 197/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.0699 - acc: 0.7715 - val_loss: 1.5644 - val_acc: 0.5094
# Epoch 198/200
# 4/4 [==============================] - 61s 15s/step - loss: 1.0830 - acc: 0.7937 - val_loss: 1.5995 - val_acc: 0.5849
# Epoch 199/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.0936 - acc: 0.7615 - val_loss: 1.5414 - val_acc: 0.4717
# Epoch 200/200
# 4/4 [==============================] - 62s 16s/step - loss: 1.0210 - acc: 0.7793 - val_loss: 1.5252 - val_acc: 0.5849

# %%
plt.plot(History.history['acc'])
plt.plot(History.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
plt.plot(History.history['loss'])
plt.plot(History.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()
